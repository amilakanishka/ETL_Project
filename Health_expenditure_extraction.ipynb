# %%
import pandas as pd

# %%
path = "Resources/raw_health_expenditure.csv"
health_df = pd.read_csv(path, encoding="utf-8")
health_df.head()
# Out:
#       HF       Financing scheme     HC  \
# 0  HFTOT  All financing schemes  HCTOT
# 1  HFTOT  All financing schemes  HCTOT
# 2  HFTOT  All financing schemes  HCTOT
# 3  HFTOT  All financing schemes  HCTOT
# 4  HFTOT  All financing schemes  HCTOT
#
#                                         Function     HP       Provider  \
# 0  Current expenditure on health (all functions)  HPTOT  All providers
# 1  Current expenditure on health (all functions)  HPTOT  All providers
# 2  Current expenditure on health (all functions)  HPTOT  All providers
# 3  Current expenditure on health (all functions)  HPTOT  All providers
# 4  Current expenditure on health (all functions)  HPTOT  All providers
#
#   MEASURE                          Measure LOCATION  Country  ...  Year  \
# 0  PARPIB  Share of gross domestic product      AUT  Austria  ...  2019
# 1  PARPIB  Share of gross domestic product      BEL  Belgium  ...  2019
# 2  PARPIB  Share of gross domestic product      DNK  Denmark  ...  2019
# ...

# %%
health_df = health_df[["Country", "Value"]]

health1 = health_df.sort_values('Country')
health1.head()
# Out:
#       Country   Value
# 16  Australia   9.334
# 0     Austria  10.408
# 1     Belgium  10.349
# 15     Canada  10.790
# 23      Chile   9.102

# %%
health = health1.rename(columns={"Country": "country", "Value": "health_expenditure"})
health
# Out:
#             country  health_expenditure
# 16        Australia               9.334
# 0           Austria              10.408
# 1           Belgium              10.349
# 15           Canada              10.790
# 23            Chile               9.102
# 26         Colombia               7.260
# 25   Czech Republic               7.759
# 2           Denmark              10.031
# 31          Estonia               6.786
# 33          Finland               9.086
# 24           France              11.186
# 10          Germany              11.654
# 3            Greece               7.791
# 19          Hungary               6.360
# 12          Iceland               8.788
# 9           Ireland               6.841
# 11           Israel               7.453
# 14            Italy               8.661
# 8             Japan              11.055
# 36            Korea               8.044
# 32           Latvia               6.255
# 5         Lithuania               6.803
# ...

# %%
health.to_csv("Data/health_expenditure_by_Country.csv", index=False, header=True)
